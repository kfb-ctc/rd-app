# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('project_data.xlsx', sheet_name = 'ERCIP', header = 1, usecols=lambda x: 'Unnamed' not in x)
df.head()
# Out:
#    Fiscal Year of Appropriation        Installation  Project #  \
# 0                          2009     MCB Camp Lejeune    P-1282
# 1                          2009     MCB Camp Lejeune    P-1142
# 2                          2009           MCB Hawaii   HI0936R
# 3                          2009      MCAGCC 29 Palms     P-181
# 4                          2009  MCAS Camp Pendleton   PA0904R
#
#                                        Project Title    Status Next Steps   \
# 0                      Solar Heating, Training Pools  Complete           -
# 1              Steam Decentralization Courthouse Bay  Complete           -
# 2  Solar Hot Water Systems for Temporary Lodging ...  Complete           -
# 3  Photovoltaic System, Buildings 2056, 2057 & 20...  Complete           -
# 4  Photovoltaic System & Exterior Lighting Ph II,...  Complete           -
#
#   MCICOM GF-PW Action Notes / Additional Information Project Description  \
# 0                   -                              -                   -
# 1                   -                              -                   -
# 2                   -                              -                   -
# 3                   -                              -                   -
# 4                   -                              -                   -
#
#   Mission Alignment  ...  Design Direction (from Project Sponsor)  \
# 0                 -  ...                                        -
# 1                 -  ...                                        -
# 2                 -  ...                                        -
# 3                 -  ...                                        -
# 4                 -  ...                                        -
#
#    RFP for D/B RFP Complete (D/B RFP Award)  D/B RFP Start  35% Design  \
# 0                                         -              -           -
# 1                                         -              -           -
# 2                                         -              -           -
# 3                                         -              -           -
# 4                                         -              -           -
#
#    D/B RFP Complete  Contract Award \n(D/B Award)  Construction Start Date  \
# 0                 -                             -                        -
# 1                 -                             -                        -
# 2                 -                             -                        -
# 3                 -                             -                        -
# 4                 -                             -                        -
#
#    Construction Completion Date (CCD) Beneficial Occupancy Date (BOD)  \
# 0                                   -                               -
# 1                                   -                               -
# 2                                   -                               -
# 3                                   -                               -
# 4                                   -                               -
#
#    Full Operational Capability (FOC)
# 0                                  -
# 1                                  -
# 2                                  -
# 3                                  -
# 4                                  -
#
# [5 rows x 37 columns]

# %%
df.dtypes
# Out:
# Fiscal Year of Appropriation                                int64
# Installation                                               object
# Project #                                                  object
# Project Title                                              object
# Status                                                     object
# Next Steps                                                 object
# MCICOM GF-PW Action                                        object
# Notes / Additional Information                             object
# Project Description                                        object
# Mission Alignment                                          object
# Initial Submission Amount (Planning 1391) ($000)          float64
# President's Budget Amount (Budget Ready 1391) ($000)      float64
# Original Authorized Amount ($000)                         float64
# Current Authorized Amount ($000)                          float64
# Current Working Estimate ($000)                           float64
# Amount Awarded ($000)                                     float64
# Initial Submission Amount (Planning 1391) ($000).1        float64
# President's Budget Amount (Budget Ready 1391) ($000).1    float64
# Original Authorized Amount ($000).1                        object
# Current Authorized Amount ($000).1                        float64
# Current Working Estimate ($000).1                         float64
# Appropriation Allocated ($000)                            float64
# Amount Awarded ($000).1                                   float64
# Construction Agent                                         object
# Acquisition Strategy                                       object
# Congressional Authorization                                object
# Final Design Authority (FDA)                               object
# Design Direction (from Project Sponsor)                    object
# RFP for D/B RFP Complete (D/B RFP Award)                   object
# D/B RFP Start                                              object
# 35% Design                                                 object
# D/B RFP Complete                                           object
# Contract Award \n(D/B Award)                               object
# Construction Start Date                                    object
# Construction Completion Date (CCD)                         object
# Beneficial Occupancy Date (BOD)                            object
# Full Operational Capability (FOC)                          object
# dtype: object

# %%
df['Status'].value_counts()
# Out:
# Advanced Planning    31
# Complete             21
# Submitted to OSD     10
# Cancelled             6
# RFP/Design            5
# Construction          2
# Awarded               1
# Acquisition           1
# Planning              1
# Name: Status, dtype: int64

# %%
df_current = df[df['Status'] != 'Complete']
df_current = df_current[df_current['Status'] != 'Cancelled']
df_current['Status'].value_counts()
# Out:
# Advanced Planning    31
# Submitted to OSD     10
# RFP/Design            5
# Construction          2
# Awarded               1
# Acquisition           1
# Planning              1
# Name: Status, dtype: int64

# %%
df_current.dtypes
# Out:
# Fiscal Year of Appropriation                                int64
# Installation                                               object
# Project #                                                  object
# Project Title                                              object
# Status                                                     object
# Next Steps                                                 object
# MCICOM GF-PW Action                                        object
# Notes / Additional Information                             object
# Project Description                                        object
# Mission Alignment                                          object
# Initial Submission Amount (Planning 1391) ($000)          float64
# President's Budget Amount (Budget Ready 1391) ($000)      float64
# Original Authorized Amount ($000)                         float64
# Current Authorized Amount ($000)                          float64
# Current Working Estimate ($000)                           float64
# Amount Awarded ($000)                                     float64
# Initial Submission Amount (Planning 1391) ($000).1        float64
# President's Budget Amount (Budget Ready 1391) ($000).1    float64
# Original Authorized Amount ($000).1                        object
# Current Authorized Amount ($000).1                        float64
# Current Working Estimate ($000).1                         float64
# Appropriation Allocated ($000)                            float64
# Amount Awarded ($000).1                                   float64
# Construction Agent                                         object
# Acquisition Strategy                                       object
# Congressional Authorization                                object
# Final Design Authority (FDA)                               object
# Design Direction (from Project Sponsor)                    object
# RFP for D/B RFP Complete (D/B RFP Award)                   object
# D/B RFP Start                                              object
# 35% Design                                                 object
# D/B RFP Complete                                           object
# Contract Award \n(D/B Award)                               object
# Construction Start Date                                    object
# Construction Completion Date (CCD)                         object
# Beneficial Occupancy Date (BOD)                            object
# Full Operational Capability (FOC)                          object
# dtype: object

# %%
df_current.head()
# Out:
#     Fiscal Year of Appropriation        Installation  Project #  \
# 24                          2018     MCB Camp Lejeune    P-1487
# 27                          2019        MCAS Beaufort     P-505
# 29                          2019      MWTC Bridgeport     P-480
# 30                          2020  MCAS Camp Pendleton     P-143
# 31                          2020         MCAS Miramar     P-266
#
#                                       Project Title        Status  \
# 24                          Camp Johnson Microgrid   Construction
# 27  Electrical Hardening and Black Start CHP System    RFP/Design
# 29    MWTC Bridgeport Energy Resilience Phase 1 & 2       Awarded
# 30    Advanced Microgrid Infrastructure Improvement   Acquisition
# 31           Additional Water Supply for Resilience  Construction
#
#                                       Next Steps   \
# 24                            Finish construction
# 27  J&A, Legal Sufficiency Review, and Finish IGA
# 29        Award P-481, Phase 2 low voltage work.
# 30                Determine how to move forward.
# 31                            Finish construction
#
#                                   MCICOM GF-PW Action  \
# 24                                               None
# 27  Continue to engage in J&A and legal sufficienc...
# 29                                               None
# 30  Engage with MCAS CP / MCIWEST to determine pat...
# 31                                               None
#
#                        Notes / Additional Information  \
# 24  Cost increase for construction award covered u...
# 27                             In design via UESC IGA
# 29  Cost increase covered using cancelled funds fr...
# 30                                                NaN
# 31  Cost increase covered using cancelled funds fr...
#
#                                   Project Description  \
# 24  Provide microgrid with upgraded electrical inf...
# 27  Minimize risk of Station-wide power outage by ...
# 29  Modernize electrical system to enhance system ...
# 30  Build Station micro-grid by integrating existi...
# 31  Mitigate water quality issues in East Miramar ...
#
#                                     Mission Alignment  ...  \
# 24  This project supports mission assurance and re...  ...
# 27  This project supports mission assurance and re...  ...
# 29  This project supports mission assurance and re...  ...
# 30  This project supports mission assurance and re...  ...
# 31  This project supports mission assurance and re...  ...
#
#     Design Direction (from Project Sponsor)  \
# 24                      2019-02-01 00:00:00
# 27                                      NaN
# 29                      2020-03-01 00:00:00
# 30                                      NaN
# 31                                      NaN
#
#     RFP for D/B RFP Complete (D/B RFP Award)        D/B RFP Start  \
# 24                       2020-11-19 00:00:00  2020-11-19 00:00:00
# 27                       2020-02-14 00:00:00  2020-02-14 00:00:00
# 29                       2020-06-09 00:00:00  2020-06-09 00:00:00
# 30                       2020-02-14 00:00:00  2020-02-14 00:00:00
# 31                       2019-11-22 00:00:00  2019-11-22 00:00:00
#
#              35% Design     D/B RFP Complete  Contract Award \n(D/B Award)  \
# 24  2021-04-02 00:00:00  2022-07-21 00:00:00           2022-09-29 00:00:00
# 27  2020-11-11 00:00:00  2023-04-28 00:00:00           2023-06-30 00:00:00
# 29  2020-08-06 00:00:00  2023-04-04 00:00:00           2023-04-19 00:00:00
# 30  2021-04-09 00:00:00  2021-11-30 00:00:00           2023-02-01 00:00:00
# 31  2020-01-15 00:00:00  2020-05-15 00:00:00           2020-11-03 00:00:00
#
#     Construction Start Date  Construction Completion Date (CCD)  \
# 24      2023-06-01 00:00:00                 2025-12-15 00:00:00
# 27      2024-04-01 00:00:00                 2027-04-01 00:00:00
# 29      2024-01-19 00:00:00                 2026-01-17 00:00:00
# 30      2023-12-01 00:00:00                 2025-12-01 00:00:00
# 31      2020-12-01 00:00:00                 2023-03-10 00:00:00
#
#    Beneficial Occupancy Date (BOD)  Full Operational Capability (FOC)
# 24             2025-12-15 00:00:00                2025-12-15 00:00:00
# 27             2027-04-01 00:00:00                2027-04-01 00:00:00
# 29             2026-01-17 00:00:00                2026-01-17 00:00:00
# 30             2025-12-01 00:00:00                2025-12-01 00:00:00
# 31             2023-03-10 00:00:00                2023-03-10 00:00:00
#
# [5 rows x 37 columns]

# %%
#convert columns to datetime
date_columns = ['Final Design Authority (FDA)', 'Design Direction (from Project Sponsor)', 'RFP for D/B RFP Complete (D/B RFP Award)', 
               'D/B RFP Start','35% Design', 'D/B RFP Complete', 'Contract Award \n(D/B Award)', 'Construction Start Date',  
               'Construction Completion Date (CCD)', 'Beneficial Occupancy Date (BOD)', 'Full Operational Capability (FOC)']

df_current[date_columns] = pd.to_datetime(df_current[date_columns])
df_current.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3318/73221974.py in <module>
#       4                'Construction Completion Date (CCD)', 'Beneficial Occupancy Date (BOD)', 'Full Operational Capability (FOC)']
#       5
# ----> 6 df_current[date_columns] = pd.to_datetime(df_current[date_columns])
#       7 df_current.head()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 890         result = _assemble_from_unit_mappings(arg, errors, tz)
#     891     elif isinstance(arg, Index):
#     892         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#     994     if len(req):
#     995         _required = ",".join(req)
# --> 996         raise ValueError(
#     997             "to assemble mappings requires at least that "
#     998             f"[year, month, day] be specified: [{_required}] is missing"
#
# ValueError: to assemble mappings requires at least that [year, month, day] be specified: [day,month,year] is missing
